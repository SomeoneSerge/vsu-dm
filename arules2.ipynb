# %%
import pandas as pd
import numpy as np
import mlxtend
from mlxtend.preprocessing import OnehotTransactions
from mlxtend.frequent_patterns import (apriori, association_rules)

# %%
VAR = 12
df = pd.read_excel('transactions.xls')
df = df.iloc[2300*(VAR-1):2300*VAR, :]

# %%
def trans_matrix(df):
    df = df.set_index(df.columns[0]).iloc[:, 0]
    trids = np.unique(df.index)
    items = np.unique(df)
    df = [
        list(df[[t]]) for t in trids
    ]
    ohe = OnehotTransactions()
    ohe.fit(df)
    df = ohe.transform(df)
    return pd.DataFrame(df, index=trids, columns=ohe.columns_)

# %%
df = trans_matrix(df)
df.head()
# Out:
#          Аналгетик  Дезодорант  Журнал  Зубная паста  Зубная щетка  Карандаши  \
# 1072463          0           0       1             0             0          0
# 1072505          0           0       0             1             0          0
# 1072532          0           0       1             0             0          0
# 1072559          0           0       0             0             0          0
# 1072613          0           0       0             0             0          0
#
#          Карта флеш-памяти  Конфеты  Лекало  Лекарство по рецепту  Мыло  \
# 1072463                  0        0       0                     0     0
# 1072505                  0        1       0                     0     0
# 1072532                  0        0       0                     0     0
# 1072559                  0        0       0                     0     0
# 1072613                  0        0       1                     0     0
#
#          Набор ручек  Оберточная бумага  Парфюм  Поздравительная открытка  \
# 1072463            0                  0       0                         0
# 1072505            0                  0       0                         1
# 1072532            0                  0       0                         0
# 1072559            1                  0       0                         0
# 1072613            0                  0       0                         0
#
#          Фломастеры  Шампунь
# 1072463           0        0
# 1072505           0        0
# 1072532           0        0
# 1072559           0        0
# 1072613           0        0

# %%
EPS = .035
fqits = apriori(df,
                min_support=EPS,
                use_colnames=True
        ).sort_values('support', ascending=False)
fqits
# Out:
#      support                             itemsets
# 1   0.244171                             [Журнал]
# 9   0.178756                        [Набор ручек]
# 6   0.157383                            [Конфеты]
# 2   0.146373                       [Зубная паста]
# 12  0.134715           [Поздравительная открытка]
# 4   0.112694                          [Карандаши]
# 11  0.092617                             [Парфюм]
# 8   0.082254                               [Мыло]
# 3   0.065415                       [Зубная щетка]
# 10  0.061528                  [Оберточная бумага]
# 7   0.055699                             [Лекало]
# 5   0.054404                  [Карта флеш-памяти]
# 16  0.042098  [Конфеты, Поздравительная открытка]
# 0   0.040803                          [Аналгетик]
# 15  0.038860              [Зубная паста, Конфеты]
# 14  0.038212   [Журнал, Поздравительная открытка]
# 13  0.036917                    [Журнал, Конфеты]

# %%
association_rules(fqits, min_threshold=EPS)
# Out:
#                   antecedants                 consequents   support  \
# 0                   (Конфеты)  (Поздравительная открытка)  0.157383
# 1  (Поздравительная открытка)                   (Конфеты)  0.134715
# 2                   (Конфеты)              (Зубная паста)  0.157383
# 3              (Зубная паста)                   (Конфеты)  0.146373
# 4                    (Журнал)  (Поздравительная открытка)  0.244171
# 5  (Поздравительная открытка)                    (Журнал)  0.134715
# 6                    (Журнал)                   (Конфеты)  0.244171
# 7                   (Конфеты)                    (Журнал)  0.157383
#
#    confidence      lift
# 0    0.267490  1.985597
# 1    0.312500  1.985597
# 2    0.246914  1.686879
# 3    0.265487  1.686879
# 4    0.156499  1.161702
# 5    0.283654  1.161702
# 6    0.151194  0.960671
# 7    0.234568  0.960671
